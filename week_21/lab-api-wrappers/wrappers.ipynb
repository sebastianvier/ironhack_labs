# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time 
from getpass import getpass

# %%
client_id = getpass()
client_secret = getpass()
# Out:
# ········
# ········

# %%
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getTrackIDs(user, playlist_id):
    """This code will get all the ids"""
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

ids = getTrackIDs('angelicadietzel', '4R0BZVh27NUJhHGLNitU08')

# %%
print(len(ids))
print(ids)
# Out:
# 54
# ...

# %%
meta = sp.track(ids[0])

def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
df.to_csv("spotify.csv", sep = ',')

# %%
df
# Out:
#                                        name                        album  \
# 0                                     Intro           You Should Be Here
# 1                        You Should Be Here           You Should Be Here
# 2                            How That Taste           You Should Be Here
# 3              Jealous (feat. Lexii Alijai)           You Should Be Here
# 4                                    Niggas           You Should Be Here
# 5                                    Wanted           You Should Be Here
# 6         The Way (feat. Chance the Rapper)           You Should Be Here
# 7                             Unconditional           You Should Be Here
# 8                                The Letter           You Should Be Here
# 9                       Runnin' - Interlude           You Should Be Here
# 10                               Be Alright           You Should Be Here
# 11  Down for You (feat. BJ The Chicago Kid)           You Should Be Here
# ...

# %%
https://open.spotify.com/playlist/21Gs9V9IfA9cw16tlznsHn?si=385395c759234fa4

# %% [markdown]
# #### Createa bigger poll of ids.

# %%
def getAlbumsIDs(artist_ids):
    """This code will get all the ids"""
    ids = []
    for i in artist_ids:
        time.sleep(.5)
        albums = sp.artist_albums(i)
        for item in albums['items']:
            ids.append(item['id'])
    return ids

def getTrackIDs(album_ids):
    """This code will get all the ids"""
    ids = []
    for i in album_ids:
        time.sleep(.2)
        playlist = sp.album(album_id=i)['tracks']
        for track in playlist['items']:
            ids.append(track['id'])
    return ids

# %%
array = ['https://open.spotify.com/artist/4vOycwLXdkMMzpZW04VW5m?si=NWp4Y3e9QGCfdBIbw9yZUQ',
        'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C?si=W2JLeb81Tw6dOz5cojmPKg',
        'https://open.spotify.com/artist/1EowJ1WwkMzkCkRomFhui7?si=jsWHc-0bT5WvM56NDKsing',
        'https://open.spotify.com/artist/6VuMaDnrHyPL1p4EHjYLi7?si=Ko58KGGXQkq7M-X6QMKeQw',
        'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H?si=2hEt9GeURZ6wmThf1e0I9Q',
        'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR?si=1H8wp0o6Tb-Rpz2Xgt7c1w',
        'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02?si=tTQlfsQVTRKILLOGNM1wBA',
        'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6?si=9BApkEL8TS2Cm9v_uCbeeg',
         'https://open.spotify.com/artist/2eEmsgWmUFMbtU7agJpnjY?si=DX3jjgubRiWkt1YblOuFlA'
        ]
albums_ids = getAlbumsIDs(array)
ids = getTrackIDs(albums_ids)
len(ids)
# Out:
# 2388

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
  if i%50 == 0:
    print(f'{i} out of {len(ids)}')
    percentage = (i/len(ids)) * 100
    print(percentage)
  time.sleep(.4)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
df.to_csv("spotify.csv", sep = ',')
# Out:
# 0 out of 2388
# 0.0
# 50 out of 2388
# 2.0938023450586267
# 100 out of 2388
# 4.1876046901172534
# 150 out of 2388
# 6.281407035175879
# 200 out of 2388
# 8.375209380234507
# 250 out of 2388
# 10.469011725293132
# 300 out of 2388
# 12.562814070351758
# 350 out of 2388
# 14.656616415410383
# 400 out of 2388
# 16.750418760469014
# 450 out of 2388
# 18.84422110552764
# 500 out of 2388
# 20.938023450586265
# 550 out of 2388
# 23.03182579564489
# 600 out of 2388
# 25.125628140703515
# 650 out of 2388
# 27.219430485762143
# 700 out of 2388
# 29.313232830820766
# 750 out of 2388
# 31.4070351758794
# 800 out of 2388
# 33.50083752093803
# 850 out of 2388
# 35.594639865996655
# 900 out of 2388
# 37.68844221105528
# 950 out of 2388
# 39.7822445561139
# 1000 out of 2388
# 41.87604690117253
# 1050 out of 2388
# 43.969849246231156
# 1100 out of 2388
# 46.06365159128978
# 1150 out of 2388
# 48.15745393634841
# 1200 out of 2388
# 50.25125628140703
# 1250 out of 2388
# 52.34505862646566
# ...

# %%
df
# Out:
#                                       name              album       artist  \
# 0     El Amor Mas Bonito - (Nueva Versión)         Legendario  Tito Nieves
# 1              Sonambulo - (Nueva Versión)         Legendario  Tito Nieves
# 2               Almohada - (Nueva Versión)         Legendario  Tito Nieves
# 3        De Mí Enamorate - (Nueva Versión)         Legendario  Tito Nieves
# 4                   Tuyo - (Nueva Versión)         Legendario  Tito Nieves
# ...                                    ...                ...          ...
# 2383                                   Hoy  Sin Restricciones     Miranda!
# 2384                             El Agente  Sin Restricciones     Miranda!
# 2385                               Navidad  Sin Restricciones     Miranda!
# 2386                              Traición  Sin Restricciones     Miranda!
# 2387                           Uno los Dos  Sin Restricciones     Miranda!
#
#      release_date  length  popularity  danceability  acousticness  \
# ...
